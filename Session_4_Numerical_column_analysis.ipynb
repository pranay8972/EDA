# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r"C:\Users\Rao\Documents\Naresh IT\DATA FILES\Visadataset.csv"
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 12 columns]

# %%
cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %% [markdown]
# **prevailing_wage column**

# %%
num
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
pwage=visa_df['prevailing_wage']
pwage
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476    279174.7900
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
min(pwage)
# Out:
# 2.1367

# %%
np.min(pwage) #numpy fam
# Out:
# 2.1367

# %%
pwage.min() #pandasfam
# Out:
# 2.1367

# %% [markdown]
# **percentile quartile**

# %%
#25 percentile value
np.percentile(pwage,25)
# Out:
# 34015.479999999996

# %%
np.quantile(pwage,0.25)
# Out:
# 34015.479999999996

# %%
np.percentile(pwage,50)
# Out:
# 70308.20999999999

# %%
np.quantile(pwage,0.5)
# Out:
# 70308.20999999999

# %%
np.percentile(pwage,75)
# Out:
# 107735.51250000001

# %%
np.quantile(pwage,0.75)
# Out:
# 107735.51250000001

# %%
l1=[]
for i in num:
    pwage=visa_df[i]
    count=pwage.count()
    mini=np.min(pwage)
    p_25=np.percentile(pwage,25)
    mean=np.mean(pwage)
    med=np.median(pwage)
    p_50=np.percentile(pwage,50)
    p_75=np.percentile(pwage,75)
    Max=np.max(pwage)
    metrics=[count,mini,p_25,mean,
             med,p_50,p_75,Max]
    l1.append(metrics)


l1
# Out:
# [[25480, -26, 1022.0, 5667.043210361067, 2109.0, 2109.0, 3504.0, 602069],
#  [25480, 1800, 1976.0, 1979.409929356358, 1997.0, 1997.0, 2005.0, 2016],
#  [25480,
#   2.1367,
#   34015.479999999996,
#   74455.81459209183,
#   70308.20999999999,
#   70308.20999999999,
#   107735.51250000001,
#   319210.27]]

# %%
pd.DataFrame(l1,index=num,columns=ID).T
# Out:
#         no_of_employees   yr_of_estab  prevailing_wage
# count       25480.00000  25480.000000     25480.000000
# min           -26.00000   1800.000000         2.136700
# 25%          1022.00000   1976.000000     34015.480000
# mean         5667.04321   1979.409929     74455.814592
# median       2109.00000   1997.000000     70308.210000
# 50%          2109.00000   1997.000000     70308.210000
# 75%          3504.00000   2005.000000    107735.512500
# max        602069.00000   2016.000000    319210.270000

# %%
l=[]
for i in num:
    pwage=visa_df[i]
    count=pwage.count()
    Min=np.min(pwage)
    p_25=np.percentile(pwage,25)
    mean=np.mean(pwage)
    median=np.median(pwage)
    p_50=np.percentile(pwage,50)
    p_75=np.percentile(pwage,75)
    Max=np.max(pwage)
    metrics=[count,Min,p_25,mean,median,p_50,p_75,Max]
    l.append(metrics)
pd.DataFrame(l,index=num,columns=ID).T
# Out:
#         no_of_employees   yr_of_estab  prevailing_wage
# count       25480.00000  25480.000000     25480.000000
# Min           -26.00000   1800.000000         2.136700
# 25%          1022.00000   1976.000000     34015.480000
# mean         5667.04321   1979.409929     74455.814592
# median       2109.00000   1997.000000     70308.210000
# 50%          2109.00000   1997.000000     70308.210000
# 75%          3504.00000   2005.000000    107735.512500
# Max        602069.00000   2016.000000    319210.270000

# %%
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %% [markdown]
# **percentile**
#
# - 25p = 34015.48
#     - there is 25% of total data that has less than wages 34015.48
# - total data= 25480
#
# - 25% of total data
#     - 25480*25/100=6370
#     - there arwe 6370 employees who has wages less than 34015.48

# %%
# step1 : total data : visa_df['prevailing_wage']
#step2: less than 25p 34015.48
#step3: create a condition 
#step4: extract the True values visa_df[con]
pwage=visa_df['prevailing_wage']
p_25=np.percentile(pwage,25)
con=pwage<p_25
len(visa_df[con])==25480*25/100
# Out:
# True

# %% [markdown]
# **emperical rule**

# %%
#u-1*sigma to u+1*sig,a = 68
#step1: means of wage
#step2: std of wage
#step3: lb=mean-1*sigma
#       lb= s1-1*s2
#step4: ub=mean+1*sigma

# %%
wage_data = visa_df['prevailing_wage']
wage_mean = wage_data.mean()
wage_std = wage_data.std()
lb=wage_mean-1*wage_std
ub=wage_mean+1*wage_std
lb,ub
con1=wage_data>lb
con2=wage_data<ub
con=con1&con2
len(visa_df[con])==68*25480/100
# Out:
# False

# %%
wage_data = visa_df['prevailing_wage']
wage_mean = wage_data.mean()
wage_std = wage_data.std()
lb=wage_mean-2*wage_std
ub=wage_mean+2*wage_std
lb,ub
con1=wage_data>lb
con2=wage_data<ub
con=con1&con2
len(visa_df[con])==95*25480/100
# Out:
# False

# %%
wage_data = visa_df['prevailing_wage']
wage_mean = wage_data.mean()
wage_std = wage_data.std()
lb=wage_mean-3*wage_std
ub=wage_mean+3*wage_std
lb,ub
con1=wage_data>lb
con2=wage_data<ub
con=con1&con2
len(visa_df[con])==99.7*25480/100
# Out:
# False

# %% [markdown]
# **emperical rule for normal distribution**

# %% [markdown]
# **the above data analysis conclude, data does not follow normality**

# %% [markdown]
# **histogram**

# %%
wage_data=visa_df['prevailing_wage']
plt.hist(wage_data)
# Out:
# (array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#           21.]),
#  array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#         1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#         2.55368643e+05, 2.87289457e+05, 3.19210270e+05]),
#  <BarContainer object of 10 artists>)

# %%
# for one interval we need two values
# 10 intervals so we need 11 values
# function retruns 3 outputs
    # count of each interval
    # interval values
    # number of intervals

# %%
wage_data=visa_df['prevailing_wage']
f,values,n=plt.hist(wage_data)

# %%
n
# Out:
# <BarContainer object of 10 artists>

# %%
values
# Out:
# array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#        1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#        2.55368643e+05, 2.87289457e+05, 3.19210270e+05])

# %%
f
# Out:
# array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#          21.])

# %%
wage_data=visa_df['prevailing_wage']
lb=2.13670000e+00
ub=3.19229500e+04
con1=wage_data>=lb
con2=wage_data<=ub
con3=con1 & con2
len(visa_df[con3])
# Out:
# 6038

# %%
wage_data=visa_df['prevailing_wage']
lb=3.19229500e+04
ub=6.38437634e+04
con1=wage_data>=lb
con2=wage_data<=ub
con3=con1 & con2
len(visa_df[con3])
# Out:
# 5504

# %% [markdown]
# - we understood percentile
#
# - we explored about empericalrule
#
# - then emperical rule failed
#
# - that means the data does not contain normal distribution
#
# - we also checked with histogram plot
#
# - histogram plot also supported our research: data does not follow normalty
#
# - i has riight skew, so that some outliers present
#
# - we need to visualize those outliers by using boxplot

# %%
plt.boxplot(wage_data,vert=False)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# step-1: q1
# step-2: q2
# step-3: q3
# step-4: iqr=q3-q1
# step-5: lb= q1-1.5*iqr
# step-6: ub=q3+1.5*iqr
# step-7: con1
# step-8: con2
# step-9: con
# step-10: get the count

# %%
q1=np.percentile(wage_data,25)
q2=np.percentile(wage_data,50)
q3=np.percentile(wage_data,75)
iqr=q3-q1
lb= q1-1.5*iqr
ub=q3+1.5*iqr
con1=wage_data<lb
von2=wage_data>ub
con=con1|con2
outliers_df=visa_df[con]
outliers_df['prevailing_wage']
outliers_df['prevailing_wage'].values
outliers_lst=outliers_df['prevailing_wage'].values.tolist()

# %%
# i want to call the each observation of wage data
# if that observation will avaialble in this 427 values
# the that observation will replace by median
# otherwise that observation will be avalable as it is

# %%
wage_median=visa_df['prevailing_wage'].median()
wage_data=visa_df['prevailing_wage']
new_wage_data=[]
for i in wage_data:
    if i in outliers_lst:
        new_wage_data.append(wage_median)
    else:
        new_wage_data.append(i)

# %%
plt.figure(figsize=(10,6))
plt.subplot(2,2,1)
plt.hist(wage_data)
plt.subplot(2,2,2)
plt.hist(new_wage_data)
plt.subplot(2,2,3)
plt.boxplot(wage_data,vert=False)
plt.subplot(2,2,4)
plt.boxplot(new_wage_data,vert=False)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.subplot(2,2,1).hist(wage_data)
plt.subplot(2,2,2).hist(new_wage_data)
plt.subplot(2,2,3).boxplot(wage_data,vert=False)
plt.subplot(2,2,4).boxplot(new_wage_data,vert=False)
plt.show()

# %% [markdown]
# **winsorization**

# %% [markdown]
# - whatever he outliers less than lb fill with lb
#
# - whatever the outliers greater than ub fill with up
#
# - in numpy we have method clip

# %%
# step-1: get the wage data values
# step-2: calculate lb 
# step-3: calculate ub
# step-: chcek the parameters and apply in numpy np.clip()
# step-5: again implement above visulaization analysis 
wage_data=visa_df['prevailing_wage']
q1 = np.percentile(wage_data, 25)
q2 = np.percentile(wage_data, 50)
q3 = np.percentile(wage_data, 75)
iqr = q3 - q1
lb = q1 - 1.5 * iqr
ub = q3 + 1.5 * iqr
wage_data_clip=np.clip(wage_data,lb,ub)

# %%
plt.figure(figsize=(10,6))
plt.subplot(2,2,1).hist(wage_data)
plt.subplot(2,2,2).hist(wage_data_clip)
plt.subplot(2,2,3).boxplot(wage_data,vert=False)
plt.subplot(2,2,4).boxplot(wage_data_clip,vert=False)
plt.show()
