# %% [markdown]
# import pandas as pd
#
# df1 = pd.DataFrame({
#     "A": [1, 2, 3],
#     "B": ["a", "b", "c"]
# })
#
# df2 = pd.DataFrame({
#     "A": [4, 5, 6],
#     "B": ["d", "e", "f"]
# })
#
# df3 = pd.DataFrame({
#     "C": [10, 20, 30]
# })
#
#
#
#
# Use to add df2 below df1.
# Use to stack df1 and df2 vertically.
# Use to join df1 and df3 horizontally (axis=1).
# Compare the results of (what differences do they observe?).
# Explain why in newer versions of pandas.

# %%
import pandas as pd

df1 = pd.DataFrame({
    "A": [1, 2, 3],
    "B": ["a", "b", "c"]
})

df2 = pd.DataFrame({
    "A": [4, 5, 6],
    "B": ["d", "e", "f"]
})

df3 = pd.DataFrame({
    "C": [10, 20, 30]
})
df1,df2,df3
# Out:
# (   A  B
#  0  1  a
#  1  2  b
#  2  3  c,
#     A  B
#  0  4  d
#  1  5  e
#  2  6  f,
#      C
#  0  10
#  1  20
#  2  30)
